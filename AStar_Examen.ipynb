# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelVelascoJr/Examen_2_IA/blob/main/AStar_Examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Clases

# %%
#Creacion de la clase CostoEstacionSO
#Esta clase se encarga de almacenar los datos de una estacion, como nombre y costo
#En la version original estaba definido como enum e int, para python se opto por string e int

class CostoEstacionSO(object):
    def __init__(self, estacion:str, costo:int):
        self.Estacion = estacion
        self.costo = costo

    def __str__(self):
        return f"{self.Estacion}"

testCostoEstacionSo1 = CostoEstacionSO("oceania",5)
testCostoEstacionSo2 = CostoEstacionSO("pantitlan",2)
print(testCostoEstacionSo1)
print(testCostoEstacionSo2)
# Out:
# oceania
# pantitlan

# %%
#Creacion de la clase CostoCaminoSO
#Esta clase se encarga de almacenar 2 estaciones de la clase "CostoEstacionSO" y el costo entre ellas 2

class CostoCaminoSO :
    #EstacionesSO #CostoEstacionSO[]
    #costo # int

    def __init__(self, Estaciones, costo:int):
        self.EstacionesSO : list[CostoEstacionSO] = Estaciones
        self.costo : int = costo

    def __str__(self):
        return f"({self.EstacionesSO[0].Estacion} a {self.EstacionesSO[1].Estacion}): {self.costo}"

    def GetEstaciones(self):
        return self.EstacionesSO;

testCostoCaminoSo = CostoCaminoSO([testCostoEstacionSo1, testCostoEstacionSo2],5)
print(testCostoCaminoSo)
# Out:
# (oceania a pantitlan): 5

# %%
#Creacion de clase CaminoRecorrido
#Esta clase almacena datos que se utilizaran durante cada ciclo
#se genera un objeto de este tipo con variables actualizadas en cada ciclo

class CaminoRecorrido(object):

    def __init__(self, nodoSO:CostoEstacionSO, caminosPorRecorrer:list[CostoCaminoSO], ListaEstacionesRecorridasEnEsteCiclo:list[CostoEstacionSO], CostoCaminoRecorrido : int = 0):
        #EstacionInicialSO almacena la una estacion, la cual se revisara durante cada ciclo
        self.EstacionInicialSO = nodoSO #CostoEstacionSO

        #CostoCaminoRecorrido almacena el costo de todos los caminos recorridos hasta este momento
        self.CostoCaminoRecorrido = CostoCaminoRecorrido  #int

        #CaminosRestantesPorRecorrer almacena todos los posibles caminos que no se han recorrido de esta estacion (nodo)
        self.CaminosRestantesPorRecorrer = caminosPorRecorrer #List<CostoCaminoSO>

        #CaminosYaRecorridos almacena los ya recorridos
        self.CaminosYaRecorridos = [] #List<CostoCaminoSO>

        #Esta lista almacena todas las estaciones por las que han pasado para llegar a esta
        #sirve para poder revisar el camino completo al final
        self.ListaEstacionesRecorridasEnEsteCiclo = ListaEstacionesRecorridasEnEsteCiclo #List<CostoEstacionSO>

    #def DetenerRecorrido(self)
    #{
    #    self.PuedeSeguir = false
    #}

    def GetPuedeSeguir(self):
        return self.PuedeSeguir

    def GetEstacionActualSO(self):
        return self.EstacionInicialSO

    def SetEstacionActual(self, Estacion):
        self.EstacionInicialSO = Estacion
        self.estacionActualVisual = EstacionInicialSO.Estacion  #EstacionesConTransbordes(enum)

    def AddToCostoCaminoRecorrido(self, Costo):
        self.CostoCaminoRecorrido += Costo

    def __str__(self):
        return "Estacion actual: {}, costo del camino recorrido: {}".format(self.EstacionInicialSO, self.CostoCaminoRecorrido)

# %% [markdown]
# # Clases para SistemaMetro
#
# Para la practica, se diseño la clase "SistemaMetro"

# %%
# Creacion de clase SistemaMetro
#Esta clase se encarga de realizar todos los calculos de A*

class SistemaMetro():

    #Datos
    #estacionesObjetivo = [] #EstacionesConTransbordes(enum)[] convertido a str[]

    #estaciones = []#List<CostoEstacionSO>
    #caminos = []#List<CostoCaminoSO>

    #Variables
    #EstacionARevisarEnElSiguienteCiclo = None#CaminoRecorrido
    #EstacionesVisitadas = []#List<CaminoRecorrido>
    #caminosPreviosYaRevisados = []#List<CostoCaminoSO>

    #Variables de ciclo
    #MaxIterations = 1#int

    #StepByStep = False#bool
    #Step = False #bool
    #SSIterationsVisual = 0 #int

    def __init__(self, estacionesObjetivo:dict[str], estaciones:CostoEstacionSO, caminos:CostoCaminoSO, EstacionARevisarEnElSiguienteCiclo:CaminoRecorrido, Iteraciones:int = 50):

        self.__PopulateClass(estacionesObjetivo, estaciones, caminos, EstacionARevisarEnElSiguienteCiclo)

        #Variables de ciclo
        self.MaxIterations = Iteraciones#int

        self.StepByStep = False#bool
        self.Step = False #bool
        self.SSIterationsVisual = 0 #int


        #RevisarDuplicados(estaciones);
        #RevisarCaminosDuplicados(caminos);

        #Aqui se encarga de revisar si el ciclo de A* llego a un resultado antes de un numero de iteraciones definido
        if(not self.StepByStep):
            for i in range(self.MaxIterations):
                self.breakVar = self.AStarCycle(i)
                if self.breakVar:
                    break

    #Esta funcion llena las variables de la clase
    def __PopulateClass(self, estacionesObjetivo:list[str], estaciones:list[CostoEstacionSO], caminos:list[CostoCaminoSO], EstacionARevisarEnElSiguienteCiclo:CaminoRecorrido):
        #Datos
        self.estacionesObjetivo = estacionesObjetivo#EstacionesConTransbordes(enum)[] convertido a str[]
        self.estaciones:list[CostoEstacionSO] = estaciones#List<CostoEstacionSO>
        self.caminos:list[CostoCaminoSO] = caminos#List<CostoCaminoSO>
        #Variables
        self.EstacionARevisarEnElSiguienteCiclo = EstacionARevisarEnElSiguienteCiclo #CaminoRecorrido
        self.EstacionesVisitadas = []#List<CaminoRecorrido>
        self.caminosPreviosYaRevisados = []#List<CostoCaminoSO>

    #Esta funcion revisa si en cada ciclo de A*, se encuentra la solucion, si si, imprime cual es, el costo
    #del camino, las iteraciones y las estaciones recorridas con colores, retorna true si encontro la solucion
    def AStarCycle(self, iterations:int)->bool:
        self.EncontroSolucion = self.AStar()
        if self.EncontroSolucion:
            log = "\033[94m found after {} iterations \033[0m \nCamino: \033[94m -".format(iterations)
            for i in range(len(self.EstacionARevisarEnElSiguienteCiclo.ListaEstacionesRecorridasEnEsteCiclo)):
            #for(int i = 0; i < self.EstacionARevisarEnElSiguienteCiclo.ListaEstacionesRecorridasEnEsteCiclo.Count; i++)
                log += "{}-".format(self.EstacionARevisarEnElSiguienteCiclo.ListaEstacionesRecorridasEnEsteCiclo[i].Estacion)
            log += "{}-".format(self.EstacionARevisarEnElSiguienteCiclo.EstacionInicialSO.Estacion)
            log += "\033[0m \nCosto del camino total sin nodo: \033[93m {}".format(self.EstacionARevisarEnElSiguienteCiclo.CostoCaminoRecorrido)
            log += "\033[0m \n\t\t\tcon nodo: \033[93m {}".format(self.EstacionARevisarEnElSiguienteCiclo.CostoCaminoRecorrido + self.NuevaEstacion.costo)
            print(log)
            return True
        return False

    # Pasos A*
    #
    # 1.- Obtener nuevos nodos hijo, agregarlos a un arreglo de todos los caminos posibles
    # 2.- Revisar de dicho arreglo, cual es el nodo con menor costo
    # 3.- Moverse al nodo con menor costo, almacenar el costo del camino hasta ese momento y el camino seguido
    # 4.- Verificar si ese nodo es el objetivo, si si terminoar, si no, repetir
    #

    #funcion definida de la implementacion de A*, se ejecuta 1 vez por ciclo
    def AStar(self) -> bool:

        print("\033[94m-------------------------\033[0m")

        #1.- Obtener nodos hijo, agregarlos a un arreglo de todos los caminos posibles
        self.BuscarCaminosEnHijosNuevos()

        #2.- Revisar de dicho arreglo, cual es el nodo con menor costo
        #PosibleOtraEstacion : CostoEstacionSO = None
        #caminoMenosCostoso: CostoCaminoSO = None
        #NuevaEstacion: CostoEstacionSO = None
        #caminoMejor: CaminoRecorrido = None
        self.PosibleOtraEstacion, self.caminoMenosCostoso, self.NuevaEstacion, self.caminoMejor = self.ObtenerCaminoDeMenorCosto()

        #debug
        #print(f"Camino menos costoso: {self.caminoMenosCostoso}\nNueva estacion: {self.NuevaEstacion}\nCamino mejor: [{self.caminoMejor}]\nEstacion actual SO: {self.EstacionARevisarEnElSiguienteCiclo.EstacionInicialSO}");

        #3.- Moverse al nodo con menor costo, almacenar el costo del camino hasta ese momento y el camino seguido
        self.MoverseAOtroNodo(self.caminoMenosCostoso, self.NuevaEstacion, self.caminoMejor);

        #4.- Verificar si ese nodo es el objetivo, si si terminoar, si no, repetir
        #for (int i = 0; i < estacionesObjetivo.Length; i++)
        for i in range(len(self.estacionesObjetivo)):
            self.estacionObjetivo = self.estacionesObjetivo[i]
            if self.estacionObjetivo == self.EstacionARevisarEnElSiguienteCiclo.EstacionInicialSO.Estacion:
                return True
        return False

    def BuscarCaminosEnHijosNuevos(self):
        self.index : int = -1
        self.containsCamino : bool = False

        for Camino in self.caminos:
            #aqui, se guardan en una variable las estaciones que estan definidas en la clase "CostoCaminoSO"
            self.estacionesQueTieneUnCamino = Camino.GetEstaciones();

            #si el camino no tiene la estacion en la que estamos, ignorar y continuar la busqueda
            if not self.EstacionARevisarEnElSiguienteCiclo.EstacionInicialSO in self.estacionesQueTieneUnCamino:
                continue

            #si el camino ya fue revisado, ignorar y continuar
            if Camino in self.caminosPreviosYaRevisados:
                continue

            #revisa si ya agregamos el camino, se ejecuta 1 vez por ciclo para agregar el camino a la
            #lista de estaciones visitadas, generando un objeto "CaminoRecorrido"
            if not self.containsCamino:
                #CopyListaEstacionesRecorridasEnEsteCiclo : list[CostoEstacionSO]
                self.CopyListaEstacionesRecorridasEnEsteCiclo = []
                for estacionRecorrida in self.EstacionARevisarEnElSiguienteCiclo.ListaEstacionesRecorridasEnEsteCiclo:

                    self.CopyListaEstacionesRecorridasEnEsteCiclo.append(estacionRecorrida)

                self.CopyListaEstacionesRecorridasEnEsteCiclo.append(self.EstacionARevisarEnElSiguienteCiclo.EstacionInicialSO)
                self.camRecorrido:CaminoRecorrido = CaminoRecorrido(self.EstacionARevisarEnElSiguienteCiclo.EstacionInicialSO, [], self.CopyListaEstacionesRecorridasEnEsteCiclo, self.EstacionARevisarEnElSiguienteCiclo.CostoCaminoRecorrido)
                self.camRecorrido.CaminosRestantesPorRecorrer.append(Camino)
                self.EstacionesVisitadas.append(self.camRecorrido)
                self.index = len(self.EstacionesVisitadas) - 1
                self.containsCamino = True
            else:
                #si el camino ya esta dentro de caminos restantes por recorrer o dentro de caminos ya recorridos, ignorar
                if Camino not in self.EstacionesVisitadas[self.index].CaminosRestantesPorRecorrer and Camino not in self.EstacionesVisitadas[self.index].CaminosYaRecorridos:
                    self.EstacionesVisitadas[self.index].CaminosRestantesPorRecorrer.append(Camino)
        #imprime los caminos restantes por recorrer en toda la lista de
        #EstacionesVisitadas (los nodos actuales y anteriores)
        log = ""
        for Estacion in self.EstacionesVisitadas:
            for CaminosRestantes in Estacion.CaminosRestantesPorRecorrer:
                log += f"{CaminosRestantes.GetEstaciones()[0]} y {CaminosRestantes.GetEstaciones()[1]}\n"
        print(log)

    #Esta funcion obtiene el camino de menor costo de todos los caminos restantes en toda la lista de
    #EstacionesVisitadas,
    def ObtenerCaminoDeMenorCosto(self):

        PosibleOtraEstacion : CostoEstacionSO = None
        caminoMenosCostoso: CostoCaminoSO = None
        NuevaEstacion: CostoEstacionSO = None
        caminoMejor: CaminoRecorrido = None

        #para todos los caminos restantes
        log :str = ""
        for EstacionVisitada in self.EstacionesVisitadas:
            for Camino in EstacionVisitada.CaminosRestantesPorRecorrer:
                #revisar cual es el camino contrario al que estamos revisando
                if (Camino.EstacionesSO[0] == EstacionVisitada.EstacionInicialSO):

                    PosibleOtraEstacion = Camino.EstacionesSO[1]

                else:

                    PosibleOtraEstacion = Camino.EstacionesSO[0]

                log += f"Posible otra estacion: {PosibleOtraEstacion} en camino: {EstacionVisitada.EstacionInicialSO}\n\t"
                #comparar el costo entre todos los nuevos caminos
                # para cuando es el primer ciclo
                if caminoMenosCostoso == None:

                    caminoMenosCostoso = Camino
                    NuevaEstacion = PosibleOtraEstacion
                    caminoMejor = EstacionVisitada
                    log += f"Primera eleccion de \033[95m{NuevaEstacion}\033[0m\n"

                #Calcular el costo de este nuevo nodo
                log += f"Hacia {PosibleOtraEstacion.Estacion}:Costo acumulado: {EstacionVisitada.CostoCaminoRecorrido}, Costo camino: {Camino.costo}, Costo nodo: {PosibleOtraEstacion.costo},\t total: \033[93m{EstacionVisitada.CostoCaminoRecorrido + Camino.costo + PosibleOtraEstacion.costo}\033[0m\n"

                costoActual:int = caminoMejor.CostoCaminoRecorrido + caminoMenosCostoso.costo + NuevaEstacion.costo
                costoOtroCamino:int = EstacionVisitada.CostoCaminoRecorrido + Camino.costo + PosibleOtraEstacion.costo

                #Compara el mejor camino con este posible nuevo camino, lo asigna si es mejor
                if costoOtroCamino < costoActual:
                    log += f"Cambio de camino de \033[95m{NuevaEstacion}\033[0m a \033[95m{PosibleOtraEstacion}\033[0m\n"
                    caminoMenosCostoso = Camino
                    NuevaEstacion = PosibleOtraEstacion
                    caminoMejor = EstacionVisitada

        #Imprime los datos del mejor camino, y devuelve variables para moverse a otro camino
        print(log)

        log2:str = ""

        log2 += f"\033[94m Camino a seguir: {caminoMenosCostoso.EstacionesSO[0].Estacion} a {caminoMenosCostoso.EstacionesSO[1].Estacion}\033[0m\n";
        log2 += f"\tMenor costo: {caminoMenosCostoso.costo + NuevaEstacion.costo}";
        log2 += f"\tcamino total menor: {caminoMejor.CostoCaminoRecorrido} + {caminoMenosCostoso.costo} + {NuevaEstacion.costo} = {caminoMejor.CostoCaminoRecorrido + caminoMenosCostoso.costo + NuevaEstacion.costo}: Estacion a moverse: \033[96m{NuevaEstacion.Estacion}\033[0m\n";

        print(log2)

        return PosibleOtraEstacion, caminoMenosCostoso, NuevaEstacion, caminoMejor

    def MoverseAOtroNodo(self, caminoMenosCostoso:CostoCaminoSO, NuevaEstacion: CostoEstacionSO, caminoMejor: CaminoRecorrido):
        #agregar caminoMenosCostoso a lista de exclusion
        self.caminosPreviosYaRevisados.append(caminoMenosCostoso)

        #agregar caminoMenosCostoso a CaminosPreviosYaRevisados
        self.caminoMejor.CaminosYaRecorridos.append(caminoMenosCostoso)
        #eliminar camino de CaminosRestantesPorRecorrer[caminoMenosCostoso]
        self.caminoMejor.CaminosRestantesPorRecorrer.remove(caminoMenosCostoso)

        #Cambiar estacionARevisarEnElSiguienteCiclo, agregas el costo total como la suma de el camino mejor y el menos costoso
        self.EstacionARevisarEnElSiguienteCiclo = CaminoRecorrido(NuevaEstacion, [], caminoMejor.ListaEstacionesRecorridasEnEsteCiclo, caminoMenosCostoso.costo + caminoMejor.CostoCaminoRecorrido)

# %%
#Testing sin datos puros
testCamRecorrido = CaminoRecorrido(testCostoEstacionSo2, [], [])
#m = SistemaMetro()
Metro = SistemaMetro(["oceania","oceania"], [testCostoEstacionSo1,testCostoEstacionSo2], [testCostoCaminoSo, testCostoCaminoSo],testCamRecorrido,Iteraciones=2)
del testCamRecorrido, Metro
# Out:
# -------------------------
# oceania y pantitlan
#
# Posible otra estacion: oceania en camino: pantitlan
# 	Primera eleccion de oceania
# Hacia oceania:Costo acumulado: 0, Costo camino: 5, Costo nodo: 5,	 total: 10
#
#  Camino a seguir: oceania a pantitlan
# 	Menor costo: 10	camino total menor: 0 + 5 + 5 = 10: Estacion a moverse: oceania
#
#  found after 0 iterations
# Camino:  -pantitlan-oceania-
# Costo del camino total sin nodo:  5
# 			con nodo:  10

# %% [markdown]
# # Generacion de Dataset

# %%
estInicialStr = "nishitakashimaradai"
Estaciones:list[CostoEstacionSO] = []
Inicial:CostoEstacionSO = None
Estnishitakashimaradai = CostoEstacionSO(estInicialStr,0) #nombreEstacion, costo

Estkasuga_i = CostoEstacionSO("kasuga_i",12)
Estkasuga_e = CostoEstacionSO("kasuga_e",7)

Estkorakuen_n = CostoEstacionSO("korakuen_n",11)
Estkorakuen_m = CostoEstacionSO("korakuen_m",22)

Esthongosanchome_e = CostoEstacionSO("hongosanchome_e", 8)
Esthongosanchome_m = CostoEstacionSO("hongosanchome_m", 21)

Estikebukuro_y = CostoEstacionSO("ikebukuro_y",9)
Estikebukuro_f = CostoEstacionSO("ikebukuro_f",9)
Estikebukuro_m = CostoEstacionSO("ikebukuro_m",25)

Estkuramae_a = CostoEstacionSO("kuramae_a",17)
Estkuramae_e = CostoEstacionSO("kuramae_e",11)

Estjimbocho_s = CostoEstacionSO("jimbocho_s",6)
Estjimbocho_i = CostoEstacionSO("jimbocho_i",10)
Estjimbocho_z = CostoEstacionSO("jimbocho_z",7)

Estkudanshita_s = CostoEstacionSO("kudanshita_s",5)
Estkudanshita_z = CostoEstacionSO("kudanshita_z",6)
Estkudanshita_t = CostoEstacionSO("kudanshita_t",7)

Estotemachi_i = CostoEstacionSO("otemachi_i",9)
Estotemachi_c = CostoEstacionSO("otemachi_c",11)
Estotemachi_t = CostoEstacionSO("otemachi_t",9)
Estotemachi_m = CostoEstacionSO("otemachi_m",18)
Estotemachi_z = CostoEstacionSO("otemachi_z",8)

Estmorishita_s = CostoEstacionSO("morishita_s",11)
Estmorishita_e = CostoEstacionSO("morishita_e",13)

Estichigaya_s = CostoEstacionSO("ichigaya_s",4)
Estichigaya_y = CostoEstacionSO("ichigaya_y",14)
Estichigaya_n = CostoEstacionSO("ichigaya_n",9)

Estnagatacho_n = CostoEstacionSO("nagatacho_n",7)
Estnagatacho_z = CostoEstacionSO("nagatacho_z",4)
Estnagatacho_y = CostoEstacionSO("nagatacho_y",16)
Estnagatacho_g = CostoEstacionSO("nagatacho_g",5)
Estnagatacho_m = CostoEstacionSO("nagatacho_m",13)

Estlidabashi_e = CostoEstacionSO("lidabashi_e",6)
Estlidabashi_t = CostoEstacionSO("lidabashi_t",6)
Estlidabashi_y = CostoEstacionSO("lidabashi_y",13)
Estlidabashi_n = CostoEstacionSO("lidabashi_n",10)

Estshinjuku_f = CostoEstacionSO("shinjuku_f",13)
Estshinjuku_s = CostoEstacionSO("shinjuku_s",2)
Estshinjuku_m = CostoEstacionSO("shinjuku_m",9)

Estyotsuya_m = CostoEstacionSO("yotsuya_m",12)
Estyotsuya_n = CostoEstacionSO("yotsuya_n",8)

Esttsukishima_y = CostoEstacionSO("tsukishima_y",21)
Esttsukishima_e = CostoEstacionSO("tsukishima_e",16)

Estazabujuban_n = CostoEstacionSO("azabujuban_n",4)
Estazabujuban_e = CostoEstacionSO("azabujuban_e",22)

Estaoyamaitchome_e = CostoEstacionSO("aoyamaitchome_e",24)
Estaoyamaitchome_z = CostoEstacionSO("aoyamaitchome_z",3)
Estaoyamaitchome_g = CostoEstacionSO("aoyamaitchome_g",4)

Estogikubo_m = CostoEstacionSO("ogikubo_m",1)

Esthigashishinjuku_e = CostoEstacionSO("higashishinjuku_e",2)
Esthigashishinjuku_f = CostoEstacionSO("higashishinjuku_f",12)

Estshinjukunishiguchi_e = CostoEstacionSO("shinjukunishiguchi_e",1)
Estshinjukunishiguchi_m = CostoEstacionSO("shinjukunishiguchi_m",8)

Estnakanosakaue_m = CostoEstacionSO("nakanosakaue_m",6)
Estnakanosakaue_e = CostoEstacionSO("nakanosakaue_e",30)

Esttochomae_e = CostoEstacionSO("tochomae_e",28)
Estyoyogi_e = CostoEstacionSO("yoyogi_e",26)

Estuenookachimachi_e = CostoEstacionSO("uenookachimachi_e",9)#estaciones hermanas, de distinto nombre
Estnakaokachimachi_h = CostoEstacionSO("nakaokachimachi_h",17)#estaciones hermanas, de distinto nombre
Estuenohirokoji_g = CostoEstacionSO("uenohirokoji_g",15)#estaciones hermanas, de distinto nombre

Estshinochanomizu_c = CostoEstacionSO("shinochanomizu_c",12)#igual aca
Estogawamachi_s = CostoEstacionSO("ogawamachi_s",7)
Estawajicho_m = CostoEstacionSO("awajicho_m",19)

Estmeijijingumae_c = CostoEstacionSO("meijijingumae_c",3)
Estmeijijingumae_f = CostoEstacionSO("meijijingumae_f",15)

Estyarakucho_y = CostoEstacionSO("yarakucho_y",18)

Estomotesando_z = CostoEstacionSO("omotesando_z",2)
Estomotesando_g = CostoEstacionSO("omotesando_g",2)
Estomotesando_c = CostoEstacionSO("omotesando_c",2)

Estakihabara_h = CostoEstacionSO("akihabara_h",16)


Estaciones = [
  Estnishitakashimaradai,

  Estkasuga_i,
  Estkasuga_e,

  Estkorakuen_n,
  Estkorakuen_m,

  Esthongosanchome_e,
  Esthongosanchome_m,

  Estikebukuro_y,
  Estikebukuro_f,
  Estikebukuro_m,

  Estkuramae_a,
  Estkuramae_e,

  Estjimbocho_s,
  Estjimbocho_i,
  Estjimbocho_z,

  Estkudanshita_s,
  Estkudanshita_z,
  Estkudanshita_t,

  Estotemachi_i,
  Estotemachi_c,
  Estotemachi_t,
  Estotemachi_m,
  Estotemachi_z,

  Estmorishita_s,
  Estmorishita_e,

  Estichigaya_s,
  Estichigaya_y,
  Estichigaya_n,

  Estnagatacho_n,
  Estnagatacho_z,
  Estnagatacho_y,
  Estnagatacho_g,
  Estnagatacho_m,

  Estlidabashi_e,
  Estlidabashi_t,
  Estlidabashi_y,
  Estlidabashi_n,

  Estshinjuku_f,
  Estshinjuku_s,
  Estshinjuku_m,

  Estyotsuya_m,
  Estyotsuya_n,

  Esttsukishima_y,
  Esttsukishima_e,

  Estazabujuban_n,
  Estazabujuban_e,

  Estaoyamaitchome_e,
  Estaoyamaitchome_z,
  Estaoyamaitchome_g,

  Estogikubo_m,

  Esthigashishinjuku_e,
  Esthigashishinjuku_f,

  Estshinjukunishiguchi_e,
  Estshinjukunishiguchi_m,

  Estnakanosakaue_m,
  Estnakanosakaue_e,

  Esttochomae_e,
  Estyoyogi_e,

  Estuenookachimachi_e,
  Estnakaokachimachi_h,
  Estuenohirokoji_g,

  Estshinochanomizu_c,
  Estogawamachi_s,
  Estawajicho_m,

  Estmeijijingumae_c,
  Estmeijijingumae_f,

  Estyarakucho_y,

  Estomotesando_z,
  Estomotesando_g,
  Estomotesando_c,

  Estakihabara_h,
]

print("Dataset de estaciones generado")
# Out:
# Dataset de estaciones generado

# %%
Caminos:list[CostoCaminoSO] = []
estacionesEnCamino = [] #2 estaciones
#caminoTesteo = CostoCaminoSO([Estjimbocho, Estkasuga]s,69)

Caminos  = [
  CostoCaminoSO([Estnishitakashimaradai, Estkasuga_i],15),
  #CostoCaminoSO([Estnishitakashimaradai, Estkasuga_e],15),
  #CostoCaminoSO([Estnishitakashimaradai, Estkorakuen_m],15),
  #CostoCaminoSO([Estnishitakashimaradai, Estkorakuen_n],15),
  CostoCaminoSO([Estkasuga_i, Estkasuga_e],0),
  CostoCaminoSO([Estkasuga_i, Estkorakuen_m],0),
  CostoCaminoSO([Estkasuga_i, Estkorakuen_n],0),
  CostoCaminoSO([Estkasuga_e, Estkorakuen_m],0),
  CostoCaminoSO([Estkasuga_e, Estkorakuen_n],0),
  CostoCaminoSO([Estkorakuen_m, Estkorakuen_n],0),

  CostoCaminoSO([Estkasuga_e, Esthongosanchome_e],1),
  CostoCaminoSO([Estkorakuen_m, Esthongosanchome_m],1),
  CostoCaminoSO([Esthongosanchome_e, Esthongosanchome_m],0),
  CostoCaminoSO([Estkorakuen_m, Estikebukuro_m],3),
  CostoCaminoSO([Estkorakuen_n, Estlidabashi_n],1),
  CostoCaminoSO([Estkasuga_e, Estlidabashi_e],1),
  CostoCaminoSO([Estkasuga_i, Estjimbocho_i],2),

  #CostoCaminoSO([Estkasuga_e, Estkuramae_e],5),
  #CostoCaminoSO([Estkuramae_e, Estkuramae_a],0),


  CostoCaminoSO([Estlidabashi_y, Estikebukuro_y],4),
  CostoCaminoSO([Estlidabashi_t, Estogikubo_m],6),
  CostoCaminoSO([Estlidabashi_e, Esthigashishinjuku_e],4),
  CostoCaminoSO([Estlidabashi_y, Estichigaya_y],1),
  CostoCaminoSO([Estlidabashi_n, Estichigaya_n],1),
  CostoCaminoSO([Estlidabashi_t, Estkudanshita_t],1),
  CostoCaminoSO([Estlidabashi_e, Estlidabashi_n],0),
  CostoCaminoSO([Estlidabashi_e, Estlidabashi_t],0),
  CostoCaminoSO([Estlidabashi_e, Estlidabashi_y],0),
  CostoCaminoSO([Estlidabashi_n, Estlidabashi_t],0),
  CostoCaminoSO([Estlidabashi_t, Estlidabashi_n],0),
  CostoCaminoSO([Estlidabashi_e, Estlidabashi_n],0),


  CostoCaminoSO([Esthigashishinjuku_f, Estikebukuro_f],3),
  CostoCaminoSO([Esthigashishinjuku_e, Estshinjukunishiguchi_e],1),
  CostoCaminoSO([Esthigashishinjuku_f, Estshinjuku_f],1),
  CostoCaminoSO([Estshinjuku_f, Estshinjuku_m],0),
  CostoCaminoSO([Estshinjuku_f, Estshinjuku_s],0),
  CostoCaminoSO([Estshinjuku_m, Estshinjuku_s],0),

  #CostoCaminoSO([Estkuramae_a, Estkuramae_e],0),
  #CostoCaminoSO([Estkuramae_e, Estkuramae_a],0),

  CostoCaminoSO([Estshinjukunishiguchi_m, Estnakanosakaue_m], 1),
  CostoCaminoSO([Estnakanosakaue_e, Estnakanosakaue_m],0),
  CostoCaminoSO([Estshinjukunishiguchi_m, Estshinjuku_m], 1),

  CostoCaminoSO([Estshinjuku_m, Estyotsuya_m],3),
  CostoCaminoSO([Estyotsuya_n, Estyotsuya_m],0),
  CostoCaminoSO([Estshinjuku_s, Estichigaya_s],2),

  CostoCaminoSO([Estogikubo_m, Estnakanosakaue_m],5),

  CostoCaminoSO([Estshinjukunishiguchi_e, Esttochomae_e],5),
  CostoCaminoSO([Estshinjukunishiguchi_e, Estshinjukunishiguchi_m],0),
  CostoCaminoSO([Estshinjukunishiguchi_e, Estyoyogi_e],1),

  CostoCaminoSO([Esthongosanchome_e, Estuenookachimachi_e],1),
  CostoCaminoSO([Esthongosanchome_m, Estawajicho_m],2),

  CostoCaminoSO([Estkudanshita_s, Estichigaya_s],1),
  CostoCaminoSO([Estkudanshita_s, Estjimbocho_s],1),
  CostoCaminoSO([Estkudanshita_z, Estjimbocho_z],1),
  CostoCaminoSO([Estkudanshita_z, Estnagatacho_z],2),
  CostoCaminoSO([Estkudanshita_t, Estotemachi_t],12),
  CostoCaminoSO([Estkudanshita_s, Estkudanshita_z],0),
  CostoCaminoSO([Estkudanshita_s, Estkudanshita_t],0),
  CostoCaminoSO([Estkudanshita_z, Estkudanshita_t],0),
  #CostoCaminoSO([Estkudanshita_z, Estnagatacho_z],3),
  #CostoCaminoSO([Estkudanshita_t, Estlidabashi_t],2),
  #CostoCaminoSO([Estkudanshita_t, Estotemachi_t],3),

  CostoCaminoSO([Estichigaya_n, Estichigaya_s],0),
  CostoCaminoSO([Estichigaya_n, Estichigaya_y],0),
  CostoCaminoSO([Estichigaya_s, Estichigaya_y],0),

  CostoCaminoSO([Estichigaya_y, Estlidabashi_y],1),
  CostoCaminoSO([Estichigaya_n, Estlidabashi_n],1),
  CostoCaminoSO([Estichigaya_s, Estshinjuku_s],2),
  CostoCaminoSO([Estichigaya_n, Estyotsuya_n],1),
  #CostoCaminoSO([Estichigaya_s, Estkudanshita_s],2),
  CostoCaminoSO([Estichigaya_y, Estnagatacho_y],2),

  CostoCaminoSO([Estshinjuku_f, Estmeijijingumae_f],2),
  CostoCaminoSO([Estmeijijingumae_c, Estmeijijingumae_f],0),

  #CostoCaminoSO([Estnagatacho_z, Estkudanshita_z],3),
  #CostoCaminoSO([Estnagatacho_n, Estyotsuya_n],2),
  #CostoCaminoSO([Estnagatacho_m, Estyotsuya_m],2),
  #CostoCaminoSO([Estnagatacho_y, Esttsukishima_y],6),
  #CostoCaminoSO([Estnagatacho_n, Estazabujuban_n],4),
  CostoCaminoSO([Estnagatacho_z, Estaoyamaitchome_z],2),
  CostoCaminoSO([Estnagatacho_g, Estaoyamaitchome_g],2),
  CostoCaminoSO([Estnagatacho_y, Estyarakucho_y],2),
  CostoCaminoSO([Estnagatacho_z, Estnagatacho_y],0),
  CostoCaminoSO([Estnagatacho_z, Estnagatacho_n],0),
  CostoCaminoSO([Estnagatacho_z, Estnagatacho_m],0),
  CostoCaminoSO([Estnagatacho_z, Estnagatacho_g],0),
  CostoCaminoSO([Estnagatacho_y, Estnagatacho_n],0),
  CostoCaminoSO([Estnagatacho_y, Estnagatacho_m],0),
  CostoCaminoSO([Estnagatacho_y, Estnagatacho_g],0),
  CostoCaminoSO([Estnagatacho_n, Estnagatacho_m],0),
  CostoCaminoSO([Estnagatacho_n, Estnagatacho_g],0),
  CostoCaminoSO([Estnagatacho_m, Estnagatacho_g],0),

  CostoCaminoSO([Estaoyamaitchome_e, Estyoyogi_e],2),
  CostoCaminoSO([Estaoyamaitchome_g, Estomotesando_g],2),
  CostoCaminoSO([Estaoyamaitchome_z, Estomotesando_z],2),
  CostoCaminoSO([Estaoyamaitchome_z, Estaoyamaitchome_e],0),
  CostoCaminoSO([Estaoyamaitchome_z, Estaoyamaitchome_g],0),
  CostoCaminoSO([Estaoyamaitchome_e, Estaoyamaitchome_g],0),
  CostoCaminoSO([Estomotesando_g, Estomotesando_z],0),
  CostoCaminoSO([Estomotesando_g, Estomotesando_c],0),
  CostoCaminoSO([Estomotesando_z, Estomotesando_c],0),
  CostoCaminoSO([Estaoyamaitchome_g,Estnagatacho_g],5),

  CostoCaminoSO([Estjimbocho_s, Estjimbocho_i],0),
  CostoCaminoSO([Estjimbocho_s, Estjimbocho_z],0),
  CostoCaminoSO([Estjimbocho_i, Estjimbocho_z],0),
  #CostoCaminoSO([Estjimbocho_s, Estkudanshita_s],2),
  #CostoCaminoSO([Estjimbocho_z, Estkudanshita_z],2),
  CostoCaminoSO([Estjimbocho_i, Estotemachi_i],9),
  CostoCaminoSO([Estjimbocho_z, Estotemachi_z],9),

  CostoCaminoSO([Estotemachi_c, Estshinochanomizu_c],1),

  CostoCaminoSO([Estuenookachimachi_e, Estakihabara_h],1),
]

print("Dataset de caminos generado")
# Out:
# Dataset de caminos generado

# %% [markdown]
# # Prueba final

# %%
#prueba final

EstacionInicial = CaminoRecorrido(Estnishitakashimaradai, Caminos, [])

Metro = SistemaMetro(["akihabara_h"], Estaciones, Caminos, EstacionInicial, Iteraciones=300)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Posible otra estacion: aoyamaitchome_e en camino: aoyamaitchome_g
# 	Hacia aoyamaitchome_e:Costo acumulado: 21, Costo camino: 0, Costo nodo: 24,	 total: 45
# Posible otra estacion: aoyamaitchome_e en camino: aoyamaitchome_g
# 	Hacia aoyamaitchome_e:Costo acumulado: 21, Costo camino: 0, Costo nodo: 24,	 total: 45
# Posible otra estacion: aoyamaitchome_e en camino: aoyamaitchome_g
# 	Hacia aoyamaitchome_e:Costo acumulado: 21, Costo camino: 0, Costo nodo: 24,	 total: 45
# Posible otra estacion: korakuen_m en camino: korakuen_n
# 	Hacia korakuen_m:Costo acumulado: 15, Costo camino: 0, Costo nodo: 22,	 total: 37
# Posible otra estacion: korakuen_m en camino: kasuga_e
# 	Hacia korakuen_m:Costo acumulado: 15, Costo camino: 0, Costo nodo: 22,	 total: 37
# Posible otra estacion: korakuen_m en camino: korakuen_n
# 	Hacia korakuen_m:Costo acumulado: 15, Costo camino: 0, Costo nodo: 22,	 total: 37
# ...
